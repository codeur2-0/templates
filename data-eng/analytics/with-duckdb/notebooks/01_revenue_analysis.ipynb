# %% [markdown]
# # Analyse de revenu avec DuckDB
#
# Après validation, DuckDB exécute une requête SQL explicite. Le résultat peut être remplacé par une table matérialisée sans changer le contrat de l analyse.

# %% [markdown]
# ## 1. Chargement et contrat
#
# On charge les objets du projet : le notebook ne duplique pas la logique métier.

# %%
from pathlib import Path

from sales_duckdb.analytics import RevenueAnalytics

revenue = RevenueAnalytics(Path("data/raw/sales.csv")).run()
revenue

# %% [markdown]
# ## Conclusion
#
# La requête est courte et testée. Sur de gros volumes, comparer le plan, partitionner les données et contrôler les coûts de scan.
