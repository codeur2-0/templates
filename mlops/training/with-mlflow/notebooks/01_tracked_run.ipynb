# %% [markdown]
# # Run de churn suivi par MLflow
#
# Le carnet lance le même objet `ExperimentRunner` que la CLI. Ainsi, une exploration et une exécution orchestrée partagent la validation et le tracking.

# %% [markdown]
# ## 1. Chargement et contrat
#
# On charge les objets du projet : le notebook ne duplique pas la logique métier.

# %%
from pathlib import Path

from churn_mlflow.runner import ExperimentRunner

result = ExperimentRunner("file:./data/mlruns", "notebook-churn", seed=42).run(
    Path("data/raw/churn.csv"), "churned", test_size=0.25, c=1.0
)
result

# %% [markdown]
# ## Conclusion
#
# Le run possède un identifiant et une métrique. La promotion doit ajouter un seuil, un model card, des tests de compatibilité et une approbation.
