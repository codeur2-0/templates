# %% [markdown]
# # Smoke test du service de modèle
#
# Ce carnet vérifie le contrat de prédiction et la version retournée avant déploiement. Il n est pas un benchmark de charge.

# %% [markdown]
# ## 1. Chargement et contrat
#
# On charge les objets du projet : le notebook ne duplique pas la logique métier.

# %%
from churn_service.model import RuleBasedModel
from churn_service.schemas import ChurnRequest

model = RuleBasedModel()
request = ChurnRequest(tenure=4, monthly_spend=29.0, support_tickets=3)
{"model_version": "2026.01.0", "probability": model.predict_probability(request)}

# %% [markdown]
# ## Conclusion
#
# Le smoke test est complémentaire aux tests d intégration, tests de charge et canary en environnement de déploiement.
